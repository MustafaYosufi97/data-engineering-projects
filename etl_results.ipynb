# %%
import sqlite3
import pandas as pd

# Använd relativ path istället för hårdkodad
conn = sqlite3.connect("./data/league_one.db")

# Läs in alla matcher sorterade på datum
df = pd.read_sql_query("SELECT * FROM matches ORDER BY date", conn)
conn.close()

# Visa tabell snyggt
df.head(20)
# Out:
#    event_id            home_team          away_team        date      time  \
# 0   2274982        AFC Wimbledon   Bolton Wanderers  2026-01-31  12:30:00
# 1   2274983             Barnsley          Stevenage  2026-01-31  15:00:00
# 2   2274984        Bradford City   Doncaster Rovers  2026-01-31  12:30:00
# 3   2274985          Exeter City   Rotherham United  2026-01-31  15:00:00
# 4   2274986        Leyton Orient          Port Vale  2026-01-31  15:00:00
# 5   2274987           Luton Town          Blackpool  2026-01-31  15:00:00
# 6   2274988       Mansfield Town  Wycombe Wanderers  2026-01-31  15:00:00
# 7   2274989     Northampton Town            Reading  2026-01-31  14:00:00
# 8   2274990  Peterborough United  Huddersfield Town  2026-01-31  15:00:00
# 9   2274991     Stockport County    Plymouth Argyle  2026-01-31  15:00:00
# 10  2274992       Wigan Athletic       Lincoln City  2026-01-31  15:00:00
# 11  2274993        Burton Albion       Cardiff City  2026-01-31  15:00:00
# ...
